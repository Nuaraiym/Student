# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('StudentsPerformance (2).csv')
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.describe().round()
# Out:
#        math score  reading score  writing score
# count      1000.0         1000.0         1000.0
# mean         66.0           69.0           68.0
# std          15.0           15.0           15.0
# min           0.0           17.0           10.0
# 25%          57.0           59.0           58.0
# 50%          66.0           70.0           69.0
# 75%          77.0           79.0           79.0
# max         100.0          100.0          100.0

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.to_csv('finish.csv',index=False)

# %%
df['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
count = df['race/ethnicity'].nunique()
print(f'unique race/ethnicity : {count}')
# Out:
# unique race/ethnicity : 5

# %%
df.groupby('race/ethnicity')['math score'].mean().round().sort_values(ascending=False).head(3)
# Out:
# race/ethnicity
# group E    74.0
# group D    67.0
# group C    64.0
# Name: math score, dtype: float64

# %%
(df['test preparation course'] == 'completed').sum()
# Out:
# np.int64(358)

# %%
df[df['test preparation course'] == 'completed']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 6    female        group B                some college      standard
# 8      male        group D                 high school  free/reduced
# 13     male        group A                some college      standard
# 18     male        group C             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.groupby('test preparation course')['math score'].mean().round()
# Out:
# test preparation course
# completed    70.0
# none         64.0
# Name: math score, dtype: float64

# %%
(df['lunch'] == 'free/reduced').sum()
# Out:
# np.int64(355)

# %%
df.groupby('lunch')['reading score'].mean().round()
# Out:
# lunch
# free/reduced    65.0
# standard        72.0
# Name: reading score, dtype: float64

# %%
#11.	Сколько учеников с уровнем образования родителей bachelor's degree
(df['parental level of education'] == "bachelor's degree").sum()
# Out:
# np.int64(118)

# %%
#11 Сколько учеников с уровнем образования родителей bacherlor's degree
df[df['parental level of education'] == "bachelor's degree"]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 24     male        group D           bachelor's degree  free/reduced
# 27   female        group C           bachelor's degree      standard
# 60     male        group E           bachelor's degree  free/reduced
# 77     male        group A           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 916    male        group E           bachelor's degree      standard
# 933    male        group C           bachelor's degree  free/reduced
# 969  female        group B           bachelor's degree      standard
# 970  female        group D           bachelor's degree      standard
# 993  female        group D           bachelor's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#14.	Средний балл по математике по уровню образования родителей
df.groupby('parental level of education')['math score'].mean().round()
# Out:
# parental level of education
# associate's degree    68.0
# bachelor's degree     69.0
# high school           62.0
# master's degree       70.0
# some college          67.0
# some high school      63.0
# Name: math score, dtype: float64

# %%
#17.	У скольких учеников math score >= 90?
df['math score'] >= 90
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: math score, Length: 1000, dtype: bool

# %%
#17
math = (df['math score'] >= 90).unique().sum()
print(f'Ученики с math score : {math}')
# Out:
# Ученики с math score : 1

# %%
#17
math = (df['math score'] >= 90).sum()
print(f'Ученики с math score : {math}')
# Out:
# Ученики с math score : 58

# %%
#17
math = df[df['math score'] >= 90]
print(f'Ученики с math score : {math}')
# Out:
# Ученики с math score :      gender race/ethnicity parental level of education         lunch  \
# 2    female        group B             master's degree      standard
# 34     male        group E                some college      standard
# 104    male        group C                some college      standard
# 114  female        group E           bachelor's degree      standard
# 121    male        group B          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
# 171    male        group E            some high school      standard
# 179  female        group D            some high school      standard
# 233    male        group E            some high school      standard
# 263  female        group E                 high school      standard
# 286    male        group E          associate's degree      standard
# ...

# %%
#20.	Создать новый столбец average_score = среднее из трех оценок.
df['average_score'] = df['math score']
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df['average_score'] = df['reading score']
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#20  Создать новый столбец average_score = среднее из трех оценок
df['average_score'] = df['math score']+ df['reading score'] + df['writing score']
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#12  Дополнительно.   Средние баллы по всем предметам по полу (gender).
df.groupby('gender')[['math score','reading score','writing score']].mean().round()
# Out:
#         math score  reading score  writing score
# gender
# female        64.0           73.0           72.0
# male          69.0           65.0           63.0

# %%
#13	У кого медианная оценка по письму выше — мужчины или женщины?
median = df.groupby('gender')['writing score'].median()
print(f'У кого медианная оценка выше : {median}')
# Out:
# У кого медианная оценка выше : gender
# female    74.0
# male      64.0
# Name: writing score, dtype: float64

# %%
#15	Группировка по test preparation course и lunch + средние оценки.
df.groupby(['test preparation course','lunch'])[['math score','reading score','writing score']].mean().round()
# Out:
#                                       math score  reading score  writing score
# test preparation course lunch
# completed               free/reduced        63.0           70.0           70.0
#                         standard            74.0           76.0           77.0
# none                    free/reduced        57.0           62.0           59.0
#                         standard            68.0           69.0           68.0

# %%
#16	Найти самого успешного ученика (максимум по сумме 3 оценок).
df['total_score'] = df['math score'] + df['reading score'] + df['writing score']
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df[df['total_score'] == 300]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 458  female        group E           bachelor's degree  standard
# 916    male        group E           bachelor's degree  standard
# 962  female        group E          associate's degree  standard
#
#     test preparation course  math score  reading score  writing score  \
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
#
#      average_score  total_score
# 458            300          300
# 916            300          300
# 962            300          300

# %%
#18
math = (df[['math score','reading score','writing score']] >= 80).sum()
print(f'Три оценки больше 80 : {math}')
# Out:
# Три оценки больше 80 : math score       193
# reading score    249
# writing score    235
# dtype: int64

# %%
#19.	Группировка по gender, race/ethnicity, mean().
df.groupby(['gender','race/ethnicity'])[['math score','reading score','writing score']].mean().round()
# Out:
#                        math score  reading score  writing score
# gender race/ethnicity
# female group A               59.0           69.0           68.0
#        group B               61.0           71.0           70.0
#        group C               62.0           72.0           72.0
#        group D               65.0           74.0           75.0
#        group E               71.0           76.0           76.0
# male   group A               64.0           62.0           59.0
#        group B               66.0           63.0           60.0
#        group C               68.0           65.0           63.0
#        group D               69.0           66.0           65.0
#        group E               77.0           70.0           67.0

# %%
#20 Создать новый столбец average_score = среднее из трех оценок
df['average_score'] = round(df['total_score'] / 3)
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# Matplotlib & Seaborn (20 задач)

# %%
# 41.	Построить histplot для math score.
plt.figure(figsize=(8,8))
sns.histplot(data=df,kde=True,x='math score',bins=20,color='red')
plt.title('Count math score')
plt.savefig('math_score.png')
plt.show()

# %%
# Старый вариант графики
sns.distplot(df['math score'],bins=20)
plt.title('Count math score')
plt.savefig('math_score.png')
plt.show()
# Out:
# /tmp/ipython-input-3252900308.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['math score'],bins=20)

# %%
#42.	Распределение average_score.
plt.figure(figsize=(8,8))
sns.histplot(data=df,kde=True,x='math score',bins=20,color='black')
plt.title('Count average score')
plt.savefig('average_score.png')
plt.show()

# %%
#43 boxplot: gender vs math score.
sns.boxplot(x='gender',y='math score',data=df)
plt.show()

# %%
#44.	violinplot: race/ethnicity vs writing score.
sns.violinplot(data=df, x='race/ethnicity', y='writing score',color='orange')
plt.title('Count race/ethnicity')
plt.show()

# %%
#45.	barplot: средние оценки по parental level of education.
plt.figure(figsize=(9,8))
sns.barplot(data=df,x='parental level of education',y='average_score')
plt.title('Average score parental level of education')
plt.show()

# %%
#6.	heatmap: корреляция между оценками.

# %%
#47.	scatterplot: math score vs writing score.
sns.scatterplot(data=df, x='math score',y='writing score')
plt.title('Math score end writing score')
plt.show()

# %%
#48.	pairplot: оценки всех предметов
sns.pairplot(df[['math score','reading score','writing score']])
plt.show()

# %%
#49.	Построить lmplot между average_score и math score.
sns.lmplot(data=df,x='average_score',y='math score')
plt.title('lmplot между average_score и math score')
plt.figure(figsize=(50,30))
plt.show()

# %%
from sklearn.linear_model import LinearRegression
lin_model = LinearRegression()

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# average_score                  0
# total_score                    0
# dtype: int64

# %%
#51.	Закодировать категориальные переменные (LabelEncoder или OneHot).
df = pd.get_dummies(df.drop(columns=['total_score', 'average_score']),
                   columns=['gender', 'race/ethnicity', 'parental level of education',
                   'lunch', 'test preparation course'],drop_first=True).astype(int)

# %%
df
# Out:
#      math score  reading score  writing score  gender_male  \
# 0            72             72             74            0
# 1            69             90             88            0
# 2            90             95             93            0
# 3            47             57             44            1
# 4            76             78             75            1
# ..          ...            ...            ...          ...
# 995          88             99             95            0
# 996          62             55             55            1
# 997          59             71             65            0
# 998          68             78             77            0
# 999          77             86             86            0
#
#      race/ethnicity_group B  race/ethnicity_group C  race/ethnicity_group D  \
# 0                         1                       0                       0
# 1                         0                       1                       0
# ...

# %%
#52.	Нормализовать числовые признаки (StandardScaler).
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
features = df.drop(columns=['writing score'])
scalet_data = scaler.fit_transform(features)
df
# Out:
#      math score  reading score  writing score  gender_male  \
# 0            72             72             74            0
# 1            69             90             88            0
# 2            90             95             93            0
# 3            47             57             44            1
# 4            76             78             75            1
# ..          ...            ...            ...          ...
# 995          88             99             95            0
# 996          62             55             55            1
# 997          59             71             65            0
# 998          68             78             77            0
# 999          77             86             86            0
#
#      race/ethnicity_group B  race/ethnicity_group C  race/ethnicity_group D  \
# 0                         1                       0                       0
# 1                         0                       1                       0
# ...

# %%
#54.	Разделить X и y (y = math score).
x = scalet_data
y = df['writing score']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lin_model = LinearRegression()

# %%
lin_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_model.predict(x_test)

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 0.9381328994057507

# %%
import joblib
joblib.dump(lin_model,'model.pkl')
joblib.dump(scaler,'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
df
# Out:
#      math score  reading score  writing score  gender_male  \
# 0            72             72             74            0
# 1            69             90             88            0
# 2            90             95             93            0
# 3            47             57             44            1
# 4            76             78             75            1
# ..          ...            ...            ...          ...
# 995          88             99             95            0
# 996          62             55             55            1
# 997          59             71             65            0
# 998          68             78             77            0
# 999          77             86             86            0
#
#      race/ethnicity_group B  race/ethnicity_group C  race/ethnicity_group D  \
# 0                         1                       0                       0
# 1                         0                       1                       0
# ...
